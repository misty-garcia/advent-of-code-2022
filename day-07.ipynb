# %% [markdown]
# # No Space Left On Device

# %% [markdown]
# ## Part 1

# %% [markdown]
# You can hear birds chirping and raindrops hitting leaves as the expedition proceeds. Occasionally, you can even hear much louder sounds in the distance; how big do the animals get out here, anyway?
#
# The device the Elves gave you has problems with more than just its communication system. You try to run a system update:
#
# $ system-update --please --pretty-please-with-sugar-on-top
# Error: No space left on device
# Perhaps you can delete some files to make space for the update?
#
# You browse around the filesystem to assess the situation and save the resulting terminal output (your puzzle input). For example:
#
# $ cd /
# $ ls
# dir a
# 14848514 b.txt
# 8504156 c.dat
# dir d
# $ cd a
# $ ls
# dir e
# 29116 f
# 2557 g
# 62596 h.lst
# $ cd e
# $ ls
# 584 i
# $ cd ..
# $ cd ..
# $ cd d
# $ ls
# 4060174 j
# 8033020 d.log
# 5626152 d.ext
# 7214296 k
# The filesystem consists of a tree of files (plain data) and directories (which can contain other directories or files). The outermost directory is called /. You can navigate around the filesystem, moving into or out of directories and listing the contents of the directory you're currently in.
#
# Within the terminal output, lines that begin with $ are commands you executed, very much like some modern computers:
#
# cd means change directory. This changes which directory is the current directory, but the specific result depends on the argument:
# cd x moves in one level: it looks in the current directory for the directory named x and makes it the current directory.
# cd .. moves out one level: it finds the directory that contains the current directory, then makes that directory the current directory.
# cd / switches the current directory to the outermost directory, /.
# ls means list. It prints out all of the files and directories immediately contained by the current directory:
# 123 abc means that the current directory contains a file named abc with size 123.
# dir xyz means that the current directory contains a directory named xyz.
# Given the commands and output in the example above, you can determine that the filesystem looks visually like this:
#
# - / (dir)
#   - a (dir)
#     - e (dir)
#       - i (file, size=584)
#     - f (file, size=29116)
#     - g (file, size=2557)
#     - h.lst (file, size=62596)
#   - b.txt (file, size=14848514)
#   - c.dat (file, size=8504156)
#   - d (dir)
#     - j (file, size=4060174)
#     - d.log (file, size=8033020)
#     - d.ext (file, size=5626152)
#     - k (file, size=7214296)
# Here, there are four directories: / (the outermost directory), a and d (which are in /), and e (which is in a). These directories also contain files of various sizes.
#
# Since the disk is full, your first step should probably be to find directories that are good candidates for deletion. To do this, you need to determine the total size of each directory. The total size of a directory is the sum of the sizes of the files it contains, directly or indirectly. (Directories themselves do not count as having any intrinsic size.)
#
# The total sizes of the directories above can be found as follows:
#
# The total size of directory e is 584 because it contains a single file i of size 584 and no other directories.
# The directory a has total size 94853 because it contains files f (size 29116), g (size 2557), and h.lst (size 62596), plus file i indirectly (a contains e which contains i).
# Directory d has total size 24933642.
# As the outermost directory, / contains every file. Its total size is 48381165, the sum of the size of every file.
# To begin, find all of the directories with a total size of at most 100000, then calculate the sum of their total sizes. In the example above, these directories are a and e; the sum of their total sizes is 95437 (94853 + 584). (As in this example, this process can count files more than once!)
#
# Find all of the directories with a total size of at most 100000. What is the sum of the total sizes of those directories?

# %%
with open('day_07_input.txt', 'r') as f:
    data = f.readlines()
data = [dat.strip() for dat in data]

# %%
data[:10]
# Out:
# ['$ cd /',
#  '$ ls',
#  '150961 cmnwnpwb',
#  '28669 hhcp.jzd',
#  'dir jssbn',
#  'dir lfrctthp',
#  '133395 lfrctthp.tlv',
#  'dir ltwmz',
#  'dir nmzntmcf',
#  'dir vhj']

# %%
data[-10:]
# Out:
# ['$ cd ..',
#  '$ cd lfrctthp',
#  '$ ls',
#  '104555 cwjbzd.hbf',
#  '56298 pldmc.hjd',
#  '27639 sppmmj.nmr',
#  '$ cd ..',
#  '$ cd tlhttrgs',
#  '$ ls',
#  '252680 zsjgqqb']

# %%
#initialize parameters
all_dicts = []
one_dict = {}
level = 0
path = ''

#cycle through all commands
for dat in data:
#     print(dat)
    
    #check if directory
    if dat.startswith('$ cd'):
        print()
        print(dat)
        
        #save directory name
        folder = dat.replace('$ cd ', '')
        
        #if dictionary has contents, save
        if len(one_dict) > 0:
            all_dicts.append(one_dict)
        
        #start new dictionary for new directory
        one_dict = {}
        
        #if at home base, keep starting params
        if folder == '/':
            path = '/'
            level = 0
            
        #if going up a level, subtract a directory
        elif folder == '..':
            path = '/'.join(path.split('/')[:-2]) + '/'
            level -= 1
            continue
            
        #all other folders add a level
        else:
            path = path + folder + '/'
            level += 1
            
        #add all pieces to single dictionary
        one_dict['directory'] = folder
        one_dict['level'] = level
        one_dict['path'] = path  
        one_dict['contents'] = []
        
    #ignore ls
    elif dat.startswith('$ ls'):
        continue
    
    #add contents to single dictionary
    else:
        print(f'content: {dat}')
        one_dict['contents'].append(dat)
        
        #if its the last element in the list, add to list of all dictionaries
        if dat == data[-1]:
            all_dicts.append(one_dict)
# Out:
# $ cd /
# content: 150961 cmnwnpwb
# content: 28669 hhcp.jzd
# content: dir jssbn
# content: dir lfrctthp
# content: 133395 lfrctthp.tlv
# content: dir ltwmz
# content: dir nmzntmcf
# content: dir vhj
# content: 256180 wbs.vmh
# content: 257693 zsntdzf
#
# $ cd jssbn
# content: 89372 dvlb
# content: dir lfrctthp
# content: dir pjzpjjq
# content: dir rbtbtt
# content: 203148 sppmmj
# content: 130200 sppmmj.bmm
# content: dir tlhttrgs
# content: 248929 vsbvlr
#
# $ cd lfrctthp
# content: dir lfrctthp
# content: dir srf
# content: 165285 vlfc
# content: 202701 wbs.vmh
#
# $ cd lfrctthp
# content: 25083 gsb.flc
#
# $ cd ..
#
# $ cd srf
# content: 20386 hcnjd.nsq
# content: 143480 jjlz.mtq
# content: dir rwvdvvsf
# content: 88782 sbmhf
# content: 143464 wbs.vmh
# content: dir wvhhr
#
# $ cd rwvdvvsf
# content: 20009 bqz
# content: 133188 czdm
#
# $ cd ..
#
# $ cd wvhhr
# content: 10445 vrwdvnh.jhf
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd pjzpjjq
# content: 14329 chgbd.zjf
# content: dir dvlb
# content: 212284 pjc
# content: dir qlrn
# content: 225566 rhzgmnb.nhd
# content: 145766 sppmmj.dzz
# content: dir vpltwcs
# content: 125853 wbs.vmh
#
# $ cd dvlb
# content: dir bjfqsb
# content: dir fnwsmj
# content: 154127 gplzm
# content: 264923 qcp.qvc
# content: dir wlhfvwl
# content: dir wrgqqts
# content: dir zhj
#
# $ cd bjfqsb
# content: dir jgltcw
#
# $ cd jgltcw
# content: 264579 shmqqjf.fwd
#
# $ cd ..
#
# $ cd ..
#
# $ cd fnwsmj
# content: dir lfrctthp
# content: dir rddpmj
#
# $ cd lfrctthp
# content: dir qdgqdtn
# content: 198919 qhjbh.fbc
# content: dir sgddcfdn
#
# $ cd qdgqdtn
# content: 230357 lbcgfp.vzq
#
# $ cd ..
#
# $ cd sgddcfdn
# content: 110212 cwjbzd.npb
# content: dir lnjln
# content: 207550 wlvdsjj
#
# $ cd lnjln
# content: 28970 tdw
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd rddpmj
# content: dir fhlnmw
#
# $ cd fhlnmw
# content: 228871 mcgdrzg
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd wlhfvwl
# content: dir rbwq
#
# $ cd rbwq
# content: 139444 jdczdlwb
# content: 66039 mnbq.sdq
#
# $ cd ..
#
# $ cd ..
#
# $ cd wrgqqts
# content: 124869 dvlb.cfl
#
# $ cd ..
#
# $ cd zhj
# content: dir hww
# content: 192363 lqn
# content: dir nqv
#
# $ cd hww
# content: 14681 czhd.bdn
# content: 232222 fgcfbrs.wqt
# content: dir pnsbrd
# content: 155416 vsw.npv
# content: 199792 wbs.vmh
# content: 44877 znpdrr.rmd
#
# $ cd pnsbrd
# content: 179442 vsbvlr
# content: 55431 zbhj.wnh
#
# $ cd ..
#
# $ cd ..
#
# $ cd nqv
# content: 262693 hnz.czd
# content: 259429 lptljbz
# content: dir rjgbm
# content: dir tlhttrgs
# content: 76496 tlhttrgs.jlv
# content: 260003 vsbvlr
#
# $ cd rjgbm
# content: 45885 fgfh.tch
# content: 42899 lfrctthp.fbc
# content: 159401 nnmg.tvz
# content: 144595 trzgtn.scg
#
# $ cd ..
#
# $ cd tlhttrgs
# content: dir cqtnvzn
# content: 220458 wbs.vmh
#
# $ cd cqtnvzn
# content: 49609 czdm
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd qlrn
# content: 150270 bflnzt
# content: 203988 bgq
# content: dir jwgd
# content: 256702 sppmmj
# content: dir wbgvqpc
#
# $ cd jwgd
# content: 57414 lmlbtpg.wdp
#
# $ cd ..
#
# $ cd wbgvqpc
# content: dir dvlb
# content: dir qfhvjtv
# content: dir tpcwhmv
#
# $ cd dvlb
# content: 118388 hhcp.jzd
#
# $ cd ..
#
# $ cd qfhvjtv
# content: 82966 lfrctthp
# content: dir mhbbpdpj
# content: 139234 wbs.vmh
#
# $ cd mhbbpdpj
# content: dir ghrbbh
#
# $ cd ghrbbh
# content: 24686 tlhttrgs
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd tpcwhmv
# content: 3666 hhcp.jzd
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd vpltwcs
# content: dir tlhttrgs
# content: 146745 vsbvlr
#
# $ cd tlhttrgs
# content: dir cchd
# content: 32682 cvbr.rmh
# content: 209102 mpdpnb
# content: 96179 wbs.vmh
#
# $ cd cchd
# content: 126044 wmrv
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd rbtbtt
# content: 169793 hzgdsb.tbs
# content: dir wqmvzg
#
# $ cd wqmvzg
# content: dir lzbj
#
# $ cd lzbj
# content: dir tnhdmqjh
#
# $ cd tnhdmqjh
# content: 5150 lfrctthp
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd tlhttrgs
# content: dir zjghthcb
# content: dir zmlpwlm
#
# $ cd zjghthcb
# content: dir dvlb
# content: dir ghzsqrn
# content: dir hvwjc
# content: dir lfrctthp
#
# $ cd dvlb
# content: 167639 dvlb.fhs
# content: 70305 qnhgn.mgn
#
# $ cd ..
#
# $ cd ghzsqrn
# content: 74556 dbrtz.lrn
# content: dir fngzpjm
# content: dir mdqbvhrr
# content: 220711 mrfjpgwj
# content: dir sfhqmzhd
# content: 67424 tlhttrgs.thf
# content: 202325 vsngvn.ttq
#
# $ cd fngzpjm
# content: dir dvlb
# content: dir ghzwdw
#
# $ cd dvlb
# content: 59824 bmvzg
# content: 184952 lfrctthp
# content: 51434 qwcttnh.pbs
# content: 206348 wbs.vmh
#
# $ cd ..
#
# $ cd ghzwdw
# content: 132594 lfrctthp
# content: 99032 tlhttrgs.cvp
#
# $ cd ..
#
# $ cd ..
#
# $ cd mdqbvhrr
# content: 32598 zsfv.qqv
#
# $ cd ..
#
# $ cd sfhqmzhd
# content: 58893 wpmbm
#
# $ cd ..
#
# $ cd ..
#
# $ cd hvwjc
# content: 233454 ccpnsjm.cwc
# content: 72232 lfrctthp
# content: dir nchvqtdq
# content: 248368 ptrlpt.gdf
# content: 222059 qgjv
# content: 69105 wbs.vmh
# content: dir wnj
#
# $ cd nchvqtdq
# content: 49931 gjwjq.jrc
#
# $ cd ..
#
# $ cd wnj
# content: 182139 ccpnsjm.cwc
# content: dir dvlb
# content: 72806 hhcp.jzd
# content: 156378 sppmmj
#
# $ cd dvlb
# content: dir cwjbzd
#
# $ cd cwjbzd
# content: dir tlhttrgs
#
# $ cd tlhttrgs
# content: 240264 vdp.wzt
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd lfrctthp
# content: 168164 ccpnsjm.cwc
# content: 68428 dcmfjn
# content: 133121 dvlb
# content: 146217 sppmmj.zjm
# content: dir thgh
# content: dir zzffz
#
# $ cd thgh
# content: dir nrntbh
# content: dir qlhbf
#
# $ cd nrntbh
# content: 139964 lfrctthp.brp
#
# $ cd ..
#
# $ cd qlhbf
# content: 115891 vsbvlr
#
# $ cd ..
#
# $ cd ..
#
# $ cd zzffz
# content: 170513 tlhttrgs.hsw
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd zmlpwlm
# content: 232644 wvjrtvps.hrb
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd lfrctthp
# content: dir cwjbzd
# content: dir dvlb
# content: 65658 fclf
# content: 191985 hhcp.jzd
# content: dir lwqdqm
# content: dir mpb
# content: dir ndn
# content: dir rtpwjds
# content: 185299 smp
# content: dir sqhvvsb
# content: dir vzh
# content: dir zzvnq
#
# $ cd cwjbzd
# content: 172122 ccpnsjm.cwc
# content: dir dfqpqqw
# content: dir lfrctthp
# content: 123102 lfrctthp.cms
# content: 73991 lqhjcbms
# content: 207693 mcnwp
# content: dir sppmmj
# content: 114128 tzrrgl
#
# $ cd dfqpqqw
# content: 67239 dgssm.crl
# content: dir rjm
#
# $ cd rjm
# content: 25830 nnwdzf
#
# $ cd ..
#
# $ cd ..
#
# $ cd lfrctthp
# content: dir fqswn
# content: 241343 jllwj.wjc
#
# $ cd fqswn
# content: 76154 ccpnsjm.cwc
# content: dir dhgghnm
# content: dir vpbwj
#
# $ cd dhgghnm
# content: 36757 jbmlssv.ndp
# content: dir sppmmj
#
# $ cd sppmmj
# content: dir dsss
#
# $ cd dsss
# content: 201519 vsbvlr
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd vpbwj
# content: 154042 ccpnsjm.cwc
# content: dir tlhttrgs
# content: 271666 vsbvlr
#
# $ cd tlhttrgs
# content: 125785 cwjbzd.lqr
# content: 19315 jdcm.mrz
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd sppmmj
# content: dir sppmmj
#
# $ cd sppmmj
# content: 161387 fwh.wtt
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd dvlb
# content: dir dnqvhtr
# content: dir jqpzj
# content: dir jvvsgbl
# content: dir tlhttrgs
#
# $ cd dnqvhtr
# content: dir jzm
# content: dir phcfgqfs
# content: dir sppmmj
# content: dir vhrst
#
# $ cd jzm
# content: 143413 sgsbj.qtr
# content: dir smtpdcpf
#
# $ cd smtpdcpf
# content: 95947 lgzlj
#
# $ cd ..
#
# $ cd ..
#
# $ cd phcfgqfs
# content: 257801 hhcp.jzd
#
# $ cd ..
#
# $ cd sppmmj
# content: 230280 ccpnsjm.cwc
# content: 261954 hhcp.jzd
# content: dir hmcn
# content: dir mrhsrrm
# content: dir nlqmghj
# content: dir rqbtcvfw
# content: 70788 vsbvlr
# content: 114344 wbs.vmh
# content: 225265 wjnf.wrv
#
# $ cd hmcn
# content: 206476 dvlb
# content: 214973 lfrctthp
#
# $ cd ..
#
# $ cd mrhsrrm
# content: 126589 wbs.vmh
#
# $ cd ..
#
# $ cd nlqmghj
# content: 113621 mdqvh.flp
#
# $ cd ..
#
# $ cd rqbtcvfw
# content: 259673 wbs.vmh
#
# $ cd ..
#
# $ cd ..
#
# $ cd vhrst
# content: 102273 sppmmj
#
# $ cd ..
#
# $ cd ..
#
# $ cd jqpzj
# content: 7675 vwls.wjz
#
# $ cd ..
#
# $ cd jvvsgbl
# content: 217539 bgjgtfbv.wcf
# content: dir fbvls
# content: dir gtwrhhd
# content: dir tlhttrgs
# content: 59720 wbs.vmh
#
# $ cd fbvls
# content: 146823 ccpnsjm.cwc
#
# $ cd ..
#
# $ cd gtwrhhd
# content: 59762 wbs.vmh
#
# $ cd ..
#
# $ cd tlhttrgs
# content: 7093 ccpnsjm.cwc
# content: dir dvlb
# content: dir hjclnb
#
# $ cd dvlb
# content: 62683 trww
#
# $ cd ..
#
# $ cd hjclnb
# content: 245444 bcnlmstj.bsj
# content: 167166 czdm
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd tlhttrgs
# content: 53060 czdm
# content: 217177 hzwn
#
# $ cd ..
#
# $ cd ..
#
# $ cd lwqdqm
# content: dir bdgnmf
# content: dir dvlb
# content: 89596 vsbvlr
#
# $ cd bdgnmf
# content: 146880 wbs.vmh
#
# $ cd ..
#
# $ cd dvlb
# content: 184438 vsbvlr
#
# $ cd ..
#
# $ cd ..
#
# $ cd mpb
# content: dir dvlb
#
# $ cd dvlb
# content: dir prqfqf
#
# $ cd prqfqf
# content: dir ltmjppj
#
# $ cd ltmjppj
# content: 241963 bjgzsq.srr
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ndn
# content: 184702 cnv.vtn
# content: 52486 dvlb
# content: dir hfq
# content: 52100 hswnvlq.frd
#
# $ cd hfq
# content: dir bsjgglbs
# content: 263904 cwjbzd.sht
# content: 265639 phpvlfw.jmm
# content: 178105 wbs.vmh
# content: 25124 wcq.qct
#
# $ cd bsjgglbs
# content: 121761 czdm
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd rtpwjds
# content: 117111 qjvrwsfl
# content: 132235 rwjf
# content: dir sdssvrst
# content: 223399 wjfdgt.ldj
#
# $ cd sdssvrst
# content: 114380 ccpnsjm.cwc
#
# $ cd ..
#
# $ cd ..
#
# $ cd sqhvvsb
# content: 7812 gjhj
# content: 239114 hhcp.jzd
# content: dir ldmwm
# content: 230777 vsbvlr
#
# $ cd ldmwm
# content: 67855 blcbqb.wpz
# content: dir cwjbzd
# content: 250365 czdm
# content: 249613 dvlb.mfq
# content: dir jdsbt
# content: 95934 tlhttrgs.wgw
#
# $ cd cwjbzd
# content: 147822 cwjbzd.lff
# content: 122632 hhcp.jzd
# content: dir llcflrds
# content: dir tlhttrgs
# content: 67326 tvptb.fzl
# content: dir wtcttdzg
#
# $ cd llcflrds
# content: dir cngdgq
#
# $ cd cngdgq
# content: 235724 lqqcfphg
#
# $ cd ..
#
# $ cd ..
#
# $ cd tlhttrgs
# content: dir cgf
# content: 67714 csb.hcw
# content: dir cwjbzd
# content: dir jvs
# content: 119180 lfrctthp.qgm
# content: dir ppsmqwn
# content: dir qqmtj
# content: dir qzmpwzvz
# content: dir zmsbqrqf
#
# $ cd cgf
# content: dir dvlb
#
# $ cd dvlb
# content: 77864 thff
#
# $ cd ..
#
# $ cd ..
#
# $ cd cwjbzd
# content: 208459 ccpnsjm.cwc
# content: 17127 dtqglmf.zgb
#
# $ cd ..
#
# $ cd jvs
# content: 142337 cwjbzd
#
# $ cd ..
#
# $ cd ppsmqwn
# content: 147277 rmwh
#
# $ cd ..
#
# $ cd qqmtj
# content: 153442 vqld.lsd
#
# $ cd ..
#
# $ cd qzmpwzvz
# content: 223666 cwjbzd.gjl
# content: 254370 gjc
#
# $ cd ..
#
# $ cd zmsbqrqf
# content: 193665 tjwclf.nzs
#
# $ cd ..
#
# $ cd ..
#
# $ cd wtcttdzg
# content: 52882 hhcp.jzd
# content: 110104 hqwgl.mtb
#
# $ cd ..
#
# $ cd ..
#
# $ cd jdsbt
# content: 77115 ccpnsjm.cwc
# content: 242705 dvlb
# content: 12624 lfrctthp
# content: 145552 sppmmj
# content: 198997 vsbvlr
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd vzh
# content: dir ccbjg
# content: 91733 czdm
# content: 89195 dvlb
# content: 212167 rvfpbl.rtq
# content: 224909 tlhttrgs.djt
# content: 72916 vpznzhs.dcd
#
# $ cd ccbjg
# content: dir mcvsbd
# content: dir sppmmj
#
# $ cd mcvsbd
# content: dir cwjbzd
# content: dir rbsv
#
# $ cd cwjbzd
# content: 224826 ccpnsjm.cwc
#
# $ cd ..
#
# $ cd rbsv
# content: 164816 lfrctthp
#
# $ cd ..
#
# $ cd ..
#
# $ cd sppmmj
# content: 85264 ccpnsjm.cwc
# content: 104511 dvlb.qgj
# content: 183533 lfrctthp.zdn
# content: 98525 wbs.vmh
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd zzvnq
# content: 107390 lfrctthp
# content: dir lznpqbrd
# content: dir pddfg
# content: 143496 prnjh.sgb
# content: dir pvdz
# content: dir vnmhs
# content: 118674 zhnh.mpl
#
# $ cd lznpqbrd
# content: 157950 dpvcgj.wlw
# content: dir dvlb
# content: 175412 dvlb.qvr
# content: dir lfrctthp
# content: 84587 pmsjdj
#
# $ cd dvlb
# content: 41223 rwr.nbz
#
# $ cd ..
#
# $ cd lfrctthp
# content: 26056 fqc.fnl
# content: 28191 lgjlw.vql
# content: dir sppmmj
# content: 262066 wbs.vmh
#
# $ cd sppmmj
# content: 246742 ccpnsjm.cwc
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd pddfg
# content: dir cwjbzd
# content: dir jbw
# content: 147410 vsbvlr
#
# $ cd cwjbzd
# content: 197956 jpzb.dcw
#
# $ cd ..
#
# $ cd jbw
# content: 247206 vsbvlr
#
# $ cd ..
#
# $ cd ..
#
# $ cd pvdz
# content: dir jctpqbgw
# content: 153177 qwcgjttm.lzm
# content: 94686 vsbvlr
#
# $ cd jctpqbgw
# content: 190424 qvm
#
# $ cd ..
#
# $ cd ..
#
# $ cd vnmhs
# content: 16118 sdhmzhlg.blf
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ltwmz
# content: 243152 bdmz
#
# $ cd ..
#
# $ cd nmzntmcf
# content: dir jqcms
# content: dir lrtsts
# content: dir lvchpdf
# content: dir qpzqp
# content: dir qrgh
# content: dir scwnmrds
#
# $ cd jqcms
# content: 105562 ccpnsjm.cwc
# content: 257512 chpr.zvl
# content: dir cwjbzd
# content: dir jzqbnpn
# content: dir ssr
# content: 117496 tlhttrgs.thg
# content: 72550 vsbvlr
#
# $ cd cwjbzd
# content: dir mwvlhzdn
# content: dir qrpllg
# content: 205638 sppmmj.gcz
#
# $ cd mwvlhzdn
# content: 272658 dvlb.bbw
#
# $ cd ..
#
# $ cd qrpllg
# content: 215810 wbs.vmh
#
# $ cd ..
#
# $ cd ..
#
# $ cd jzqbnpn
# content: 112583 sppmmj
#
# $ cd ..
#
# $ cd ssr
# content: 66781 hpfpw.pvn
# content: 138840 zhwplzd.wrq
#
# $ cd ..
#
# $ cd ..
#
# $ cd lrtsts
# content: dir drtrdnsg
# content: 41195 dvlb.fgt
# content: dir lfrctthp
#
# $ cd drtrdnsg
# content: dir gnc
# content: dir sppmmj
#
# $ cd gnc
# content: 127922 ccpnsjm.cwc
# content: 233097 lfrctthp
# content: 24075 qtglzq
#
# $ cd ..
#
# $ cd sppmmj
# content: 128955 czdm
# content: 64809 jtjh.nzq
# content: dir mdmh
# content: dir nbzh
# content: 126095 wbs.vmh
# content: dir wwhbgg
#
# $ cd mdmh
# content: dir zvtjfz
#
# $ cd zvtjfz
# content: 142470 ptp.qbf
#
# $ cd ..
#
# $ cd ..
#
# $ cd nbzh
# content: 7112 ccpnsjm.cwc
# content: 215395 chrtbjf.fwr
# content: 145865 wld.pdl
#
# $ cd ..
#
# $ cd wwhbgg
# content: 51752 hhcp.jzd
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd lfrctthp
# content: 198780 hhcp.jzd
#
# $ cd ..
#
# $ cd ..
#
# $ cd lvchpdf
# content: 108580 hhcp.jzd
# content: 105301 jpjjhshl
# content: dir njfmmj
# content: dir nsw
# content: dir sppmmj
# content: dir tlhttrgs
# content: dir tvsvr
#
# $ cd njfmmj
# content: dir bjsvdfrf
# content: dir gjgftj
# content: dir sppmmj
# content: 25879 twzprtcf.hgl
#
# $ cd bjsvdfrf
# content: 77668 vsbvlr
#
# $ cd ..
#
# $ cd gjgftj
# content: dir mjbw
# content: 56593 vsbvlr
#
# $ cd mjbw
# content: 243595 ccpnsjm.cwc
#
# $ cd ..
#
# $ cd ..
#
# $ cd sppmmj
# content: dir qzvwhr
#
# $ cd qzvwhr
# content: dir cwjbzd
#
# $ cd cwjbzd
# content: 262825 wbs.vmh
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd nsw
# content: 210254 rgqpq
#
# $ cd ..
#
# $ cd sppmmj
# content: 55463 cwjbzd.dtt
# content: 196779 dvlb
# content: 125377 hgb.qmj
# content: dir rdd
# content: dir tlhttrgs
# content: 222280 tspz
# content: dir zbq
#
# $ cd rdd
# content: 20045 srmsmr
#
# $ cd ..
#
# $ cd tlhttrgs
# content: 47256 wbs.vmh
#
# $ cd ..
#
# $ cd zbq
# content: 223951 cwjbzd.vrm
#
# $ cd ..
#
# $ cd ..
#
# $ cd tlhttrgs
# content: 56808 jvndrcmd.ftl
# content: dir mjcmhg
# content: 220385 prh.wtz
# content: 231575 pzbtlg.fzv
# content: 11100 sqfr.lzs
# content: dir tlhttrgs
#
# $ cd mjcmhg
# content: 214188 llsfnv.dmc
#
# $ cd ..
#
# $ cd tlhttrgs
# content: dir qtws
# content: dir sbhswjld
#
# $ cd qtws
# content: 102462 vjlwzbsg.whn
#
# $ cd ..
#
# $ cd sbhswjld
# content: 159193 dvlb.bqj
# content: 17424 hhcp.jzd
# content: 28945 pdwrmgs.lzq
# content: 38201 rpbllgs.rzn
# content: dir sppmmj
#
# $ cd sppmmj
# content: 88100 wbs.vmh
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd tvsvr
# content: 237626 tlhttrgs.mhw
#
# $ cd ..
#
# $ cd ..
#
# $ cd qpzqp
# content: dir ddclns
# content: 134373 lfrctthp
# content: 167788 lstwpqbq.wln
# content: 224743 qcplm
# content: 14385 vzjj.bzm
# content: 108204 wbs.vmh
#
# $ cd ddclns
# content: dir vprlq
#
# $ cd vprlq
# content: 137784 ccpnsjm.cwc
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd qrgh
# content: 29875 ccpnsjm.cwc
# content: 225323 hhcp.jzd
# content: 135470 tlhttrgs
# content: 23724 vsbvlr
#
# $ cd ..
#
# $ cd scwnmrds
# content: dir sppmmj
#
# $ cd sppmmj
# content: dir sppmmj
#
# $ cd sppmmj
# content: 73173 blznf.smd
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd vhj
# content: 221377 cwjbzd.tvv
# content: 98748 czdm
# content: 108605 hhcp.jzd
# content: dir jnm
# content: dir lfrctthp
# content: 11518 lfrctthp.jfl
# content: 89038 psnfcwpq.zcd
# content: dir tlhttrgs
#
# $ cd jnm
# content: 66785 bfwm
# content: 196636 dssh.rwn
# content: dir sppmmj
# content: 140177 tlhttrgs.jlh
# content: 199730 vsbvlr
#
# $ cd sppmmj
# content: 101586 ccpnsjm.cwc
# content: dir lfrctthp
# content: 127582 vsbvlr
# content: 71001 zvrzs
#
# $ cd lfrctthp
# content: 122902 lfrctthp
# content: 247157 svmpmrl.tcc
#
# $ cd ..
#
# $ cd ..
#
# $ cd ..
#
# $ cd lfrctthp
# content: 104555 cwjbzd.hbf
# content: 56298 pldmc.hjd
# content: 27639 sppmmj.nmr
#
# $ cd ..
#
# $ cd tlhttrgs
# content: 252680 zsjgqqb

# %%
all_dicts[:5]
# Out:
# [{'directory': '/',
#   'level': 0,
#   'path': '/',
#   'contents': ['150961 cmnwnpwb',
#    '28669 hhcp.jzd',
#    'dir jssbn',
#    'dir lfrctthp',
#    '133395 lfrctthp.tlv',
#    'dir ltwmz',
#    'dir nmzntmcf',
#    'dir vhj',
#    '256180 wbs.vmh',
#    '257693 zsntdzf']},
#  {'directory': 'jssbn',
#   'level': 1,
#   'path': '/jssbn/',
#   'contents': ['89372 dvlb',
#    'dir lfrctthp',
#    'dir pjzpjjq',
#    'dir rbtbtt',
#    '203148 sppmmj',
#    '130200 sppmmj.bmm',
#    'dir tlhttrgs',
#    '248929 vsbvlr']},
#  {'directory': 'lfrctthp',
#   'level': 2,
#   'path': '/jssbn/lfrctthp/',
#   'contents': ['dir lfrctthp', 'dir srf', '165285 vlfc', '202701 wbs.vmh']},
#  {'directory': 'lfrctthp',
#   'level': 3,
#   'path': '/jssbn/lfrctthp/lfrctthp/',
#   'contents': ['25083 gsb.flc']},
#  {'directory': 'srf',
#   'level': 3,
#   'path': '/jssbn/lfrctthp/srf/',
#   'contents': ['20386 hcnjd.nsq',
#    '143480 jjlz.mtq',
#    'dir rwvdvvsf',
#    '88782 sbmhf',
#    '143464 wbs.vmh',
#    'dir wvhhr']}]

# %%
for one_dict in all_dicts:
    file_size = 0
    dir_sizes = 0
    
    #cycle through contents of each dictionary
    for content in one_dict['contents']:
        first_piece = content.split(' ')[0]
        
        #if the file starts with a number, capture it's size
        if first_piece.isdigit():
            file_size += int(first_piece)
    #save total file sizes
    one_dict['file_sizes'] = file_size
    
    #capture all subdirectories
    dirs = [content for content in one_dict['contents'] if content.startswith('dir')]
    
    #count number of subdirectories
    one_dict['num_subdir'] = len(dirs)
     
    #initialize subdirectory size to 0
    one_dict['subdir_sizes'] = 0
            
    #set directory size to size of total files
    one_dict['directory_size'] = one_dict['file_sizes'] + one_dict['subdir_sizes']

# %%
import pandas as pd

# %%
#make df for manipulation
df = pd.DataFrame(all_dicts)
df
# Out:
#     directory  level                       path  \
# 0           /      0                          /
# 1       jssbn      1                    /jssbn/
# 2    lfrctthp      2           /jssbn/lfrctthp/
# 3    lfrctthp      3  /jssbn/lfrctthp/lfrctthp/
# 4         srf      3       /jssbn/lfrctthp/srf/
# ..        ...    ...                        ...
# 186       jnm      2                  /vhj/jnm/
# 187    sppmmj      3           /vhj/jnm/sppmmj/
# 188  lfrctthp      4  /vhj/jnm/sppmmj/lfrctthp/
# 189  lfrctthp      2             /vhj/lfrctthp/
# 190  tlhttrgs      2             /vhj/tlhttrgs/
#
#                                               contents  file_sizes  \
# 0    [150961 cmnwnpwb, 28669 hhcp.jzd, dir jssbn, d...      826898
# 1    [89372 dvlb, dir lfrctthp, dir pjzpjjq, dir rb...      671649
# 2    [dir lfrctthp, dir srf, 165285 vlfc, 202701 wb...      367986
# 3                                      [25083 gsb.flc]       25083
# 4    [20386 hcnjd.nsq, 143480 jjlz.mtq, dir rwvdvvs...      396112
# ..                                                 ...         ...
# 186  [66785 bfwm, 196636 dssh.rwn, dir sppmmj, 1401...      603328
# 187  [101586 ccpnsjm.cwc, dir lfrctthp, 127582 vsbv...      300169
# 188              [122902 lfrctthp, 247157 svmpmrl.tcc]      370059
# 189  [104555 cwjbzd.hbf, 56298 pldmc.hjd, 27639 spp...      188492
# 190                                   [252680 zsjgqqb]      252680
#
#      num_subdir  subdir_sizes  directory_size
# 0             5             0          826898
# 1             4             0          671649
# 2             2             0          367986
# 3             0             0           25083
# 4             2             0          396112
# ..          ...           ...             ...
# 186           1             0          603328
# 187           1             0          300169
# 188           0             0          370059
# 189           0             0          188492
# 190           0             0          252680
#
# [191 rows x 8 columns]

# %%
#only look at directories with subdirectories & start at the lowest level
subset = df [df.num_subdir > 0]
subset = subset.sort_values('level', ascending=False)
subset
# Out:
#     directory  level                                             path  \
# 56     cwjbzd      7  /jssbn/tlhttrgs/zjghthcb/hvwjc/wnj/dvlb/cwjbzd/
# 26   tlhttrgs      6            /jssbn/pjzpjjq/dvlb/zhj/nqv/tlhttrgs/
# 114       cgf      6     /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/cgf/
# 71     sppmmj      6  /lfrctthp/cwjbzd/lfrctthp/fqswn/dhgghnm/sppmmj/
# 33   mhbbpdpj      6    /jssbn/pjzpjjq/qlrn/wbgvqpc/qfhvjtv/mhbbpdpj/
# ..        ...    ...                                              ...
# 64   lfrctthp      1                                       /lfrctthp/
# 142  nmzntmcf      1                                       /nmzntmcf/
# 1       jssbn      1                                          /jssbn/
# 185       vhj      1                                            /vhj/
# 0           /      0                                                /
#
#                                               contents  file_sizes  \
# 56                                      [dir tlhttrgs]           0
# 26                       [dir cqtnvzn, 220458 wbs.vmh]      220458
# 114                                         [dir dvlb]           0
# 71                                          [dir dsss]           0
# 33                                        [dir ghrbbh]           0
# ..                                                 ...         ...
# 64   [dir cwjbzd, dir dvlb, 65658 fclf, 191985 hhcp...      442942
# 142  [dir jqcms, dir lrtsts, dir lvchpdf, dir qpzqp...           0
# 1    [89372 dvlb, dir lfrctthp, dir pjzpjjq, dir rb...      671649
# 185  [221377 cwjbzd.tvv, 98748 czdm, 108605 hhcp.jz...      529286
# 0    [150961 cmnwnpwb, 28669 hhcp.jzd, dir jssbn, d...      826898
#
#      num_subdir  subdir_sizes  directory_size
# 56            1             0               0
# 26            1             0          220458
# 114           1             0               0
# 71            1             0               0
# 33            1             0               0
# ..          ...           ...             ...
# 64            9             0          442942
# 142           6             0               0
# 1             4             0          671649
# 185           3             0          529286
# 0             5             0          826898
#
# [94 rows x 8 columns]

# %%
for x in subset.index:
    print(subset.loc[x].directory)
    
    #get subdirectories for one directory
    subdirs = [content.split(' ')[1] for content in subset.loc[x].contents if content.startswith('dir')]
    print(subdirs)
    
    #find each subdirectory and get it's size
    subdirs_sizes_ls = []
    for subdir in subdirs:
        find_subdir = subset.loc[x].path + subdir + '/'
        print(find_subdir)
        subdir_size = df [df.path == find_subdir].directory_size.values[0]
        subdirs_sizes_ls.append(subdir_size)
        print(subdir_size)
        
    #add all the subdirectory sizes together
    df.loc[x,'subdir_sizes'] = sum(subdirs_sizes_ls)
    
    #calculate new directory size based on subdirectories
    df.loc[x,'directory_size'] = df.loc[x,'subdir_sizes'] + df.loc[x,'file_sizes']
    print()
# Out:
# cwjbzd
# ['tlhttrgs']
# /jssbn/tlhttrgs/zjghthcb/hvwjc/wnj/dvlb/cwjbzd/tlhttrgs/
# 240264
#
# tlhttrgs
# ['cqtnvzn']
# /jssbn/pjzpjjq/dvlb/zhj/nqv/tlhttrgs/cqtnvzn/
# 49609
#
# cgf
# ['dvlb']
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/cgf/dvlb/
# 77864
#
# sppmmj
# ['dsss']
# /lfrctthp/cwjbzd/lfrctthp/fqswn/dhgghnm/sppmmj/dsss/
# 201519
#
# mhbbpdpj
# ['ghrbbh']
# /jssbn/pjzpjjq/qlrn/wbgvqpc/qfhvjtv/mhbbpdpj/ghrbbh/
# 24686
#
# sgddcfdn
# ['lnjln']
# /jssbn/pjzpjjq/dvlb/fnwsmj/lfrctthp/sgddcfdn/lnjln/
# 28970
#
# dvlb
# ['cwjbzd']
# /jssbn/tlhttrgs/zjghthcb/hvwjc/wnj/dvlb/cwjbzd/
# 240264
#
# qfhvjtv
# ['mhbbpdpj']
# /jssbn/pjzpjjq/qlrn/wbgvqpc/qfhvjtv/mhbbpdpj/
# 24686
#
# vpbwj
# ['tlhttrgs']
# /lfrctthp/cwjbzd/lfrctthp/fqswn/vpbwj/tlhttrgs/
# 145100
#
# llcflrds
# ['cngdgq']
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/llcflrds/cngdgq/
# 235724
#
# thgh
# ['nrntbh', 'qlhbf']
# /jssbn/tlhttrgs/zjghthcb/lfrctthp/thgh/nrntbh/
# 139964
# /jssbn/tlhttrgs/zjghthcb/lfrctthp/thgh/qlhbf/
# 115891
#
# mdmh
# ['zvtjfz']
# /nmzntmcf/lrtsts/drtrdnsg/sppmmj/mdmh/zvtjfz/
# 142470
#
# qzvwhr
# ['cwjbzd']
# /nmzntmcf/lvchpdf/njfmmj/sppmmj/qzvwhr/cwjbzd/
# 262825
#
# dhgghnm
# ['sppmmj']
# /lfrctthp/cwjbzd/lfrctthp/fqswn/dhgghnm/sppmmj/
# 201519
#
# sbhswjld
# ['sppmmj']
# /nmzntmcf/lvchpdf/tlhttrgs/tlhttrgs/sbhswjld/sppmmj/
# 88100
#
# lfrctthp
# ['qdgqdtn', 'sgddcfdn']
# /jssbn/pjzpjjq/dvlb/fnwsmj/lfrctthp/qdgqdtn/
# 230357
# /jssbn/pjzpjjq/dvlb/fnwsmj/lfrctthp/sgddcfdn/
# 346732
#
# fngzpjm
# ['dvlb', 'ghzwdw']
# /jssbn/tlhttrgs/zjghthcb/ghzsqrn/fngzpjm/dvlb/
# 502558
# /jssbn/tlhttrgs/zjghthcb/ghzsqrn/fngzpjm/ghzwdw/
# 231626
#
# wnj
# ['dvlb']
# /jssbn/tlhttrgs/zjghthcb/hvwjc/wnj/dvlb/
# 240264
#
# nqv
# ['rjgbm', 'tlhttrgs']
# /jssbn/pjzpjjq/dvlb/zhj/nqv/rjgbm/
# 392780
# /jssbn/pjzpjjq/dvlb/zhj/nqv/tlhttrgs/
# 270067
#
# hww
# ['pnsbrd']
# /jssbn/pjzpjjq/dvlb/zhj/hww/pnsbrd/
# 234873
#
# rddpmj
# ['fhlnmw']
# /jssbn/pjzpjjq/dvlb/fnwsmj/rddpmj/fhlnmw/
# 228871
#
# tlhttrgs
# ['cgf', 'cwjbzd', 'jvs', 'ppsmqwn', 'qqmtj', 'qzmpwzvz', 'zmsbqrqf']
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/cgf/
# 77864
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/cwjbzd/
# 225586
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/jvs/
# 142337
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/ppsmqwn/
# 147277
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/qqmtj/
# 153442
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/qzmpwzvz/
# 478036
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/zmsbqrqf/
# 193665
#
# lfrctthp
# ['sppmmj']
# /lfrctthp/zzvnq/lznpqbrd/lfrctthp/sppmmj/
# 246742
#
# prqfqf
# ['ltmjppj']
# /lfrctthp/mpb/dvlb/prqfqf/ltmjppj/
# 241963
#
# jzm
# ['smtpdcpf']
# /lfrctthp/dvlb/dnqvhtr/jzm/smtpdcpf/
# 95947
#
# fqswn
# ['dhgghnm', 'vpbwj']
# /lfrctthp/cwjbzd/lfrctthp/fqswn/dhgghnm/
# 238276
# /lfrctthp/cwjbzd/lfrctthp/fqswn/vpbwj/
# 570808
#
# sppmmj
# ['mdmh', 'nbzh', 'wwhbgg']
# /nmzntmcf/lrtsts/drtrdnsg/sppmmj/mdmh/
# 142470
# /nmzntmcf/lrtsts/drtrdnsg/sppmmj/nbzh/
# 368372
# /nmzntmcf/lrtsts/drtrdnsg/sppmmj/wwhbgg/
# 51752
#
# mcvsbd
# ['cwjbzd', 'rbsv']
# /lfrctthp/vzh/ccbjg/mcvsbd/cwjbzd/
# 224826
# /lfrctthp/vzh/ccbjg/mcvsbd/rbsv/
# 164816
#
# lfrctthp
# ['thgh', 'zzffz']
# /jssbn/tlhttrgs/zjghthcb/lfrctthp/thgh/
# 255855
# /jssbn/tlhttrgs/zjghthcb/lfrctthp/zzffz/
# 170513
#
# tlhttrgs
# ['dvlb', 'hjclnb']
# /lfrctthp/dvlb/jvvsgbl/tlhttrgs/dvlb/
# 62683
# /lfrctthp/dvlb/jvvsgbl/tlhttrgs/hjclnb/
# 412610
#
# sppmmj
# ['hmcn', 'mrhsrrm', 'nlqmghj', 'rqbtcvfw']
# /lfrctthp/dvlb/dnqvhtr/sppmmj/hmcn/
# 421449
# /lfrctthp/dvlb/dnqvhtr/sppmmj/mrhsrrm/
# 126589
# /lfrctthp/dvlb/dnqvhtr/sppmmj/nlqmghj/
# 113621
# /lfrctthp/dvlb/dnqvhtr/sppmmj/rqbtcvfw/
# 259673
#
# hvwjc
# ['nchvqtdq', 'wnj']
# /jssbn/tlhttrgs/zjghthcb/hvwjc/nchvqtdq/
# 49931
# /jssbn/tlhttrgs/zjghthcb/hvwjc/wnj/
# 651587
#
# tlhttrgs
# ['cchd']
# /jssbn/pjzpjjq/vpltwcs/tlhttrgs/cchd/
# 126044
#
# tlhttrgs
# ['qtws', 'sbhswjld']
# /nmzntmcf/lvchpdf/tlhttrgs/tlhttrgs/qtws/
# 102462
# /nmzntmcf/lvchpdf/tlhttrgs/tlhttrgs/sbhswjld/
# 331863
#
# bjfqsb
# ['jgltcw']
# /jssbn/pjzpjjq/dvlb/bjfqsb/jgltcw/
# 264579
#
# fnwsmj
# ['lfrctthp', 'rddpmj']
# /jssbn/pjzpjjq/dvlb/fnwsmj/lfrctthp/
# 776008
# /jssbn/pjzpjjq/dvlb/fnwsmj/rddpmj/
# 228871
#
# wlhfvwl
# ['rbwq']
# /jssbn/pjzpjjq/dvlb/wlhfvwl/rbwq/
# 205483
#
# zhj
# ['hww', 'nqv']
# /jssbn/pjzpjjq/dvlb/zhj/hww/
# 881861
# /jssbn/pjzpjjq/dvlb/zhj/nqv/
# 1521468
#
# wbgvqpc
# ['dvlb', 'qfhvjtv', 'tpcwhmv']
# /jssbn/pjzpjjq/qlrn/wbgvqpc/dvlb/
# 118388
# /jssbn/pjzpjjq/qlrn/wbgvqpc/qfhvjtv/
# 246886
# /jssbn/pjzpjjq/qlrn/wbgvqpc/tpcwhmv/
# 3666
#
# cwjbzd
# ['llcflrds', 'tlhttrgs', 'wtcttdzg']
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/llcflrds/
# 235724
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/tlhttrgs/
# 1605101
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/wtcttdzg/
# 162986
#
# sppmmj
# ['qzvwhr']
# /nmzntmcf/lvchpdf/njfmmj/sppmmj/qzvwhr/
# 262825
#
# lzbj
# ['tnhdmqjh']
# /jssbn/rbtbtt/wqmvzg/lzbj/tnhdmqjh/
# 5150
#
# gjgftj
# ['mjbw']
# /nmzntmcf/lvchpdf/njfmmj/gjgftj/mjbw/
# 243595
#
# ghzsqrn
# ['fngzpjm', 'mdqbvhrr', 'sfhqmzhd']
# /jssbn/tlhttrgs/zjghthcb/ghzsqrn/fngzpjm/
# 734184
# /jssbn/tlhttrgs/zjghthcb/ghzsqrn/mdqbvhrr/
# 32598
# /jssbn/tlhttrgs/zjghthcb/ghzsqrn/sfhqmzhd/
# 58893
#
# sppmmj
# ['rdd', 'tlhttrgs', 'zbq']
# /nmzntmcf/lvchpdf/sppmmj/rdd/
# 20045
# /nmzntmcf/lvchpdf/sppmmj/tlhttrgs/
# 47256
# /nmzntmcf/lvchpdf/sppmmj/zbq/
# 223951
#
# cwjbzd
# ['mwvlhzdn', 'qrpllg']
# /nmzntmcf/jqcms/cwjbzd/mwvlhzdn/
# 272658
# /nmzntmcf/jqcms/cwjbzd/qrpllg/
# 215810
#
# ldmwm
# ['cwjbzd', 'jdsbt']
# /lfrctthp/sqhvvsb/ldmwm/cwjbzd/
# 2341591
# /lfrctthp/sqhvvsb/ldmwm/jdsbt/
# 676993
#
# pddfg
# ['cwjbzd', 'jbw']
# /lfrctthp/zzvnq/pddfg/cwjbzd/
# 197956
# /lfrctthp/zzvnq/pddfg/jbw/
# 247206
#
# tlhttrgs
# ['mjcmhg', 'tlhttrgs']
# /nmzntmcf/lvchpdf/tlhttrgs/mjcmhg/
# 214188
# /nmzntmcf/lvchpdf/tlhttrgs/tlhttrgs/
# 434325
#
# drtrdnsg
# ['gnc', 'sppmmj']
# /nmzntmcf/lrtsts/drtrdnsg/gnc/
# 385094
# /nmzntmcf/lrtsts/drtrdnsg/sppmmj/
# 882453
#
# lznpqbrd
# ['dvlb', 'lfrctthp']
# /lfrctthp/zzvnq/lznpqbrd/dvlb/
# 41223
# /lfrctthp/zzvnq/lznpqbrd/lfrctthp/
# 563055
#
# ccbjg
# ['mcvsbd', 'sppmmj']
# /lfrctthp/vzh/ccbjg/mcvsbd/
# 389642
# /lfrctthp/vzh/ccbjg/sppmmj/
# 471833
#
# njfmmj
# ['bjsvdfrf', 'gjgftj', 'sppmmj']
# /nmzntmcf/lvchpdf/njfmmj/bjsvdfrf/
# 77668
# /nmzntmcf/lvchpdf/njfmmj/gjgftj/
# 300188
# /nmzntmcf/lvchpdf/njfmmj/sppmmj/
# 262825
#
# ddclns
# ['vprlq']
# /nmzntmcf/qpzqp/ddclns/vprlq/
# 137784
#
# sppmmj
# ['sppmmj']
# /nmzntmcf/scwnmrds/sppmmj/sppmmj/
# 73173
#
# pvdz
# ['jctpqbgw']
# /lfrctthp/zzvnq/pvdz/jctpqbgw/
# 190424
#
# sppmmj
# ['lfrctthp']
# /vhj/jnm/sppmmj/lfrctthp/
# 370059
#
# dfqpqqw
# ['rjm']
# /lfrctthp/cwjbzd/dfqpqqw/rjm/
# 25830
#
# dnqvhtr
# ['jzm', 'phcfgqfs', 'sppmmj', 'vhrst']
# /lfrctthp/dvlb/dnqvhtr/jzm/
# 239360
# /lfrctthp/dvlb/dnqvhtr/phcfgqfs/
# 257801
# /lfrctthp/dvlb/dnqvhtr/sppmmj/
# 1823963
# /lfrctthp/dvlb/dnqvhtr/vhrst/
# 102273
#
# wqmvzg
# ['lzbj']
# /jssbn/rbtbtt/wqmvzg/lzbj/
# 5150
#
# lfrctthp
# ['fqswn']
# /lfrctthp/cwjbzd/lfrctthp/fqswn/
# 885238
#
# vpltwcs
# ['tlhttrgs']
# /jssbn/pjzpjjq/vpltwcs/tlhttrgs/
# 464007
#
# qlrn
# ['jwgd', 'wbgvqpc']
# /jssbn/pjzpjjq/qlrn/jwgd/
# 57414
# /jssbn/pjzpjjq/qlrn/wbgvqpc/
# 368940
#
# sppmmj
# ['sppmmj']
# /lfrctthp/cwjbzd/sppmmj/sppmmj/
# 161387
#
# dvlb
# ['bjfqsb', 'fnwsmj', 'wlhfvwl', 'wrgqqts', 'zhj']
# /jssbn/pjzpjjq/dvlb/bjfqsb/
# 264579
# /jssbn/pjzpjjq/dvlb/fnwsmj/
# 1004879
# /jssbn/pjzpjjq/dvlb/wlhfvwl/
# 205483
# /jssbn/pjzpjjq/dvlb/wrgqqts/
# 124869
# /jssbn/pjzpjjq/dvlb/zhj/
# 2595692
#
# zjghthcb
# ['dvlb', 'ghzsqrn', 'hvwjc', 'lfrctthp']
# /jssbn/tlhttrgs/zjghthcb/dvlb/
# 237944
# /jssbn/tlhttrgs/zjghthcb/ghzsqrn/
# 1390691
# /jssbn/tlhttrgs/zjghthcb/hvwjc/
# 1546736
# /jssbn/tlhttrgs/zjghthcb/lfrctthp/
# 942298
#
# jvvsgbl
# ['fbvls', 'gtwrhhd', 'tlhttrgs']
# /lfrctthp/dvlb/jvvsgbl/fbvls/
# 146823
# /lfrctthp/dvlb/jvvsgbl/gtwrhhd/
# 59762
# /lfrctthp/dvlb/jvvsgbl/tlhttrgs/
# 482386
#
# srf
# ['rwvdvvsf', 'wvhhr']
# /jssbn/lfrctthp/srf/rwvdvvsf/
# 153197
# /jssbn/lfrctthp/srf/wvhhr/
# 10445
#
# dvlb
# ['prqfqf']
# /lfrctthp/mpb/dvlb/prqfqf/
# 241963
#
# hfq
# ['bsjgglbs']
# /lfrctthp/ndn/hfq/bsjgglbs/
# 121761
#
# qpzqp
# ['ddclns']
# /nmzntmcf/qpzqp/ddclns/
# 137784
#
# lvchpdf
# ['njfmmj', 'nsw', 'sppmmj', 'tlhttrgs', 'tvsvr']
# /nmzntmcf/lvchpdf/njfmmj/
# 666560
# /nmzntmcf/lvchpdf/nsw/
# 210254
# /nmzntmcf/lvchpdf/sppmmj/
# 891151
# /nmzntmcf/lvchpdf/tlhttrgs/
# 1168381
# /nmzntmcf/lvchpdf/tvsvr/
# 237626
#
# scwnmrds
# ['sppmmj']
# /nmzntmcf/scwnmrds/sppmmj/
# 73173
#
# lfrctthp
# ['lfrctthp', 'srf']
# /jssbn/lfrctthp/lfrctthp/
# 25083
# /jssbn/lfrctthp/srf/
# 559754
#
# jnm
# ['sppmmj']
# /vhj/jnm/sppmmj/
# 670228
#
# rbtbtt
# ['wqmvzg']
# /jssbn/rbtbtt/wqmvzg/
# 5150
#
# tlhttrgs
# ['zjghthcb', 'zmlpwlm']
# /jssbn/tlhttrgs/zjghthcb/
# 4117669
# /jssbn/tlhttrgs/zmlpwlm/
# 232644
#
# pjzpjjq
# ['dvlb', 'qlrn', 'vpltwcs']
# /jssbn/pjzpjjq/dvlb/
# 4614552
# /jssbn/pjzpjjq/qlrn/
# 1037314
# /jssbn/pjzpjjq/vpltwcs/
# 610752
#
# sqhvvsb
# ['ldmwm']
# /lfrctthp/sqhvvsb/ldmwm/
# 3682351
#
# cwjbzd
# ['dfqpqqw', 'lfrctthp', 'sppmmj']
# /lfrctthp/cwjbzd/dfqpqqw/
# 93069
# /lfrctthp/cwjbzd/lfrctthp/
# 1126581
# /lfrctthp/cwjbzd/sppmmj/
# 161387
#
# rtpwjds
# ['sdssvrst']
# /lfrctthp/rtpwjds/sdssvrst/
# 114380
#
# lrtsts
# ['drtrdnsg', 'lfrctthp']
# /nmzntmcf/lrtsts/drtrdnsg/
# 1267547
# /nmzntmcf/lrtsts/lfrctthp/
# 198780
#
# jqcms
# ['cwjbzd', 'jzqbnpn', 'ssr']
# /nmzntmcf/jqcms/cwjbzd/
# 694106
# /nmzntmcf/jqcms/jzqbnpn/
# 112583
# /nmzntmcf/jqcms/ssr/
# 205621
#
# dvlb
# ['dnqvhtr', 'jqpzj', 'jvvsgbl', 'tlhttrgs']
# /lfrctthp/dvlb/dnqvhtr/
# 2423397
# /lfrctthp/dvlb/jqpzj/
# 7675
# /lfrctthp/dvlb/jvvsgbl/
# 966230
# /lfrctthp/dvlb/tlhttrgs/
# 270237
#
# zzvnq
# ['lznpqbrd', 'pddfg', 'pvdz', 'vnmhs']
# /lfrctthp/zzvnq/lznpqbrd/
# 1022227
# /lfrctthp/zzvnq/pddfg/
# 592572
# /lfrctthp/zzvnq/pvdz/
# 438287
# /lfrctthp/zzvnq/vnmhs/
# 16118
#
# lwqdqm
# ['bdgnmf', 'dvlb']
# /lfrctthp/lwqdqm/bdgnmf/
# 146880
# /lfrctthp/lwqdqm/dvlb/
# 184438
#
# vzh
# ['ccbjg']
# /lfrctthp/vzh/ccbjg/
# 861475
#
# mpb
# ['dvlb']
# /lfrctthp/mpb/dvlb/
# 241963
#
# ndn
# ['hfq']
# /lfrctthp/ndn/hfq/
# 854533
#
# lfrctthp
# ['cwjbzd', 'dvlb', 'lwqdqm', 'mpb', 'ndn', 'rtpwjds', 'sqhvvsb', 'vzh', 'zzvnq']
# /lfrctthp/cwjbzd/
# 2072073
# /lfrctthp/dvlb/
# 3667539
# /lfrctthp/lwqdqm/
# 420914
# /lfrctthp/mpb/
# 241963
# /lfrctthp/ndn/
# 1143821
# /lfrctthp/rtpwjds/
# 587125
# /lfrctthp/sqhvvsb/
# 4160054
# /lfrctthp/vzh/
# 1552395
# /lfrctthp/zzvnq/
# 2438764
#
# nmzntmcf
# ['jqcms', 'lrtsts', 'lvchpdf', 'qpzqp', 'qrgh', 'scwnmrds']
# /nmzntmcf/jqcms/
# 1565430
# /nmzntmcf/lrtsts/
# 1507522
# /nmzntmcf/lvchpdf/
# 3387853
# /nmzntmcf/qpzqp/
# 787277
# /nmzntmcf/qrgh/
# 414392
# /nmzntmcf/scwnmrds/
# 73173
#
# jssbn
# ['lfrctthp', 'pjzpjjq', 'rbtbtt', 'tlhttrgs']
# /jssbn/lfrctthp/
# 952823
# /jssbn/pjzpjjq/
# 6986416
# /jssbn/rbtbtt/
# 174943
# /jssbn/tlhttrgs/
# 4350313
#
# vhj
# ['jnm', 'lfrctthp', 'tlhttrgs']
# /vhj/jnm/
# 1273556
# /vhj/lfrctthp/
# 188492
# /vhj/tlhttrgs/
# 252680
#
# /
# ['jssbn', 'lfrctthp', 'ltwmz', 'nmzntmcf', 'vhj']
# /jssbn/
# 13136144
# /lfrctthp/
# 16727590
# /ltwmz/
# 243152
# /nmzntmcf/
# 7735647
# /vhj/
# 2244014

# %%
#find all dictories with a size of 100,00 or less and add them together
df [df.directory_size <= 100_000].directory_size.sum()
# Out:
# 1443806

# %% [markdown]
# ## Part 2

# %% [markdown]
# Now, you're ready to choose a directory to delete.
#
# The total disk space available to the filesystem is 70000000. To run the update, you need unused space of at least 30000000. You need to find a directory you can delete that will free up enough space to run the update.
#
# In the example above, the total size of the outermost directory (and thus the total amount of used space) is 48381165; this means that the size of the unused space must currently be 21618835, which isn't quite the 30000000 required by the update. Therefore, the update still requires a directory with total size of at least 8381165 to be deleted before it can run.
#
# To achieve this, you have the following options:
#
# Delete directory e, which would increase unused space by 584.
# Delete directory a, which would increase unused space by 94853.
# Delete directory d, which would increase unused space by 24933642.
# Delete directory /, which would increase unused space by 48381165.
# Directories e and a are both too small; deleting them would not free up enough space. However, directories d and / are both big enough! Between these, choose the smallest: d, increasing unused space by 24933642.
#
# Find the smallest directory that, if deleted, would free up enough space on the filesystem to run the update. What is the total size of that directory?

# %%
total_space = 70000000
total_used = df.loc[0,'directory_size']
total_needed = 30000000

# %%
total_space - total_used
# Out:
# 29086555

# %%
total_needed - (total_space - total_used)
# Out:
# 913445

# %%
df [df.directory_size >= 913445].sort_values('directory_size').head(1)
# Out:
#    directory  level                                path  \
# 58  lfrctthp      4  /jssbn/tlhttrgs/zjghthcb/lfrctthp/
#
#                                              contents  file_sizes  num_subdir  \
# 58  [168164 ccpnsjm.cwc, 68428 dcmfjn, 133121 dvlb...      515930           2
#
#     subdir_sizes  directory_size
# 58        426368          942298

# %%
total_space - total_used + 942298
# Out:
# 30028853
